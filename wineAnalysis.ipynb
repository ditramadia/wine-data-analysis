# %% [markdown]
# # Tugas Besar Probailitas dan Statistika IF2220
#
# ## Contributors
# 1. Ditra Rizqa Amadia (13521019)
# 2. Kenny Benaya Nathan (13521023)

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("./dataset/anggur.csv")

# %% [markdown]
# ### Soal 1
# Deskripsi Statisika (Descriptive Statistics) yang terdiri dari mean, median, modus, standar deviasi, variansi, range, nilai minimum, maksimum, kuartil, IQR, skewness dan kurtosis

# %%
desc = {}
desc[""] = []
desc["Mean"] = []
desc["Median"] = []
desc["Modus"] = []
desc["Std"] = []
desc["Variance"] = []
desc["Range"] = []
desc["Min"] = []
desc["Max"] = []
desc["Q1"] = []
desc["Q2"] = []
desc["Q3"] = []
desc["Q4"] = []
desc["IQR"] = []
desc["Skewness"] = []
desc["Kurtosis"] = []

for column in data:
    desc[""].append(column)
    desc["Mean"].append(data[column].mean())
    desc["Median"].append(data[column].median())
    desc["Modus"].append(data[column].mode("index")[0])
    desc["Std"].append(data[column].std())
    desc["Variance"].append(data[column].var())
    desc["Range"].append(data[column].max() - data[column].min())
    desc["Min"].append(data[column].min())
    desc["Max"].append(data[column].max())
    desc["Q1"].append(data[column].quantile(0.25))
    desc["Q2"].append(data[column].quantile(0.5))
    desc["Q3"].append(data[column].quantile(0.75))
    desc["Q4"].append(data[column].quantile(1))
    desc["IQR"].append(data[column].quantile(0.75) - data[column].quantile(0.25))
    desc["Skewness"].append((3 * (data[column].mean() - data[column].median()))/data[column].std())
    desc["Kurtosis"].append(data[column].kurtosis())
    

descDataFrame = pd.DataFrame(data=desc)

descDataFrame
# Out:
#                                Mean     Median      Modus       Std  \
# 0          fixed acidity   7.152530   7.150000   6.540000  1.201598
# 1       volatile acidity   0.520839   0.524850   0.554600  0.095848
# 2            citric acid   0.270517   0.272200   0.301900  0.049098
# 3         residual sugar   2.567104   2.519430   0.032555  0.987915
# 4              chlorides   0.081195   0.082167   0.015122  0.020111
# 5    free sulfur dioxide  14.907679  14.860346   0.194679  4.888100
# 6   total sulfur dioxide  40.290150  40.190000  35.200000  9.965767
# 7                density   0.995925   0.996000   0.995900  0.002020
# 8                     pH   3.303610   3.300000   3.340000  0.104875
# 9              sulphates   0.598390   0.595000   0.590000  0.100819
# 10               alcohol  10.592280  10.610000   9.860000  1.510706
# 11               quality   7.958000   8.000000   8.000000  0.902802
#
#      Variance      Range       Min        Max         Q1         Q2  \
# ...

# %% [markdown]
# ### Soal 2
# Visualisasi plot distribusi, dalam bentuk histogram dan boxplot

# %% [markdown]
# #### Fixed Acidity

# %%
data['fixed acidity'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('fixed acidity')
# Out:
# <Axes: >

# %% [markdown]
# #### Volatile Acidity

# %%
data['volatile acidity'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('volatile acidity')
# Out:
# <Axes: >

# %% [markdown]
# #### Citric Acid

# %%
data['citric acid'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('citric acid')
# Out:
# <Axes: >

# %% [markdown]
# #### Residual Sugar

# %%
data['residual sugar'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('residual sugar')
# Out:
# <Axes: >

# %% [markdown]
# #### Chlorides

# %%
data['chlorides'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('chlorides')
# Out:
# <Axes: >

# %% [markdown]
# #### Free Sulfur Dioxide

# %%
data['free sulfur dioxide'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('free sulfur dioxide')
# Out:
# <Axes: >

# %% [markdown]
# #### Total Sulfur Dioxide

# %%
data['total sulfur dioxide'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('free sulfur dioxide')
# Out:
# <Axes: >

# %% [markdown]
# #### Density

# %%
data['density'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('density')
# Out:
# <Axes: >

# %% [markdown]
# #### pH

# %%
data['pH'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('pH')
# Out:
# <Axes: >

# %% [markdown]
# #### Sulphates

# %%
data['sulphates'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('sulphates')
# Out:
# <Axes: >

# %% [markdown]
# #### Alcohol

# %%
data['alcohol'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('alcohol')
# Out:
# <Axes: >

# %% [markdown]
# #### Quality

# %%
data['quality'].hist()
# Out:
# <Axes: >

# %%
data.boxplot('quality')
# Out:
# <Axes: >
